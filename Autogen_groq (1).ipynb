# %%
# Install AutoGen Studio and pyngrok
# !pip install -q autogenstudio pyngrok

# Verify the installation
# !autogenstudio version
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.8/929.8 kB 52.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.3/344.3 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 26.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.4/819.4 kB 35.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 MB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.1/113.1 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.6/435.6 kB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 81.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 111.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 15.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.2.0 which is incompatible.
# AutoGen Studio  CLI version: 0.4.2.2

# %%
import os
import getpass

# 1. Set up Groq API Key
if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API Key: ")

# 2. Set up Ngrok Auth Token (Required to tunnel the AutoGen Studio UI)
NGROK_TOKEN = getpass.getpass("Enter your Ngrok Auth Token: ")
# !ngrok config add-authtoken {NGROK_TOKEN}
# Out:
# Enter your Ngrok Auth Token: ··········
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import multiprocessing
import time
from pyngrok import ngrok

def run_autogen_studio():
    # Launch AutoGen Studio on port 8081
    # !autogenstudio ui --port 8081 --host 0.0.0.0

# Start AutoGen Studio in a background process
process = multiprocessing.Process(target=run_autogen_studio)
process.start()

# Wait a moment for the server to spin up
time.sleep(5)

# Open the ngrok tunnel to port 8081
public_url = ngrok.connect(8081)
print("\n" + "="*60)
print(f"[SUCCESS] AutoGen Studio is running!")
print(f"Click the link below to open the UI:")
print(f"{public_url}")
print("="*60 + "\n")
# Out:
# ============================================================
# [SUCCESS] AutoGen Studio is running!
# Click the link below to open the UI:
# NgrokTunnel: "https://wired-awhile-dropout.ngrok-free.dev" -> "http://localhost:8081"
# ============================================================

# %%
import os
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_ext.models.openai import OpenAIChatCompletionClient

async def run_team():
    # Fetch the Groq API key you securely entered in Cell 2
    groq_key = ""

    # Define Groq model clients with the correct model_info settings
    researcher_model = OpenAIChatCompletionClient(
        model="llama-3.1-8b-instant",
        base_url="https://api.groq.com/openai/v1",
        api_key=groq_key,
        model_info={
            "vision": False,
            "function_calling": True,
            "json_output": True,
            "structured_output": True,
            "family": "unknown"
        }
    )

    editor_model = OpenAIChatCompletionClient(
        model="llama-3.3-70b-versatile",
        base_url="https://api.groq.com/openai/v1",
        api_key=groq_key,
        model_info={
            "vision": False,
            "function_calling": True,
            "json_output": True,
            "structured_output": True,
            "family": "unknown"
        }
    )

    # Define the individual Agents
    researcher = AssistantAgent(
        name="Researcher",
        model_client=researcher_model,
        system_message="You are an expert researcher. Provide a highly detailed summary using clear Markdown formatting."
    )

    editor = AssistantAgent(
        name="Editor",
        model_client=editor_model,
        system_message="You are a strict editor. Critique the researcher's work and optimize it for professional delivery."
    )

    # Orchestrate the workflow team
    team = RoundRobinGroupChat(
        participants=[researcher, editor],
        termination_condition=MaxMessageTermination(max_messages=4)
    )

    # Run the prompt
    print("--- Starting Multi-Agent Session ---")
    async for message in team.run_stream(task="Explain why Groq LPUs provide higher throughput for LLMs than standard GPUs."):
        print(f"\n\033[1m[{message.source}]\033[0m: {message.content}")
        print("-" * 40)

# Execute the async loop inside Google Colab
await run_team()
# Out:
# --- Starting Multi-Agent Session ---
#
# [user]: Explain why Groq LPUs provide higher throughput for LLMs than standard GPUs.
# ----------------------------------------
#
# [Researcher]: **Groq LPUs: Enabling High-Throughput Large Language Models**
# ===========================================================
#
# ### Introduction
#
# In recent years, Large Language Models (LLMs) have gained significant attention for their ability to process and generate human-like language. However, training and running these models require immense computational resources, leading to a demand for more efficient and specialized hardware.
#
# **Groq LPUs: A Breakthrough in Custom Hardware Design**
# ---------------------------------------------------
#
# [Groq LPUs](https://www.groq.com/) (Large Processor Arrays) are a new class of custom-built processors designed specifically for high-throughput applications such as LLMs. These LPUs are built around a scalable, massively parallel architecture, which provides a significant advantage over standard GPUs in certain workloads.
#
# ### Key Features of Groq LPUs
#
# #### 1. Massive Parallelism
#
# Groq LPUs are built around a large array of processing units, each capable of executing a significant number of operations simultaneously. This massive parallelism enables the LPU to process a large volume of data in parallel, leading to a significant increase in throughput.
#
# #### 2. Interconnect Fabric
#
# Groq LPUs feature a high-bandwidth, low-latency interconnect fabric that enables efficient communication between processing units. This fabric is designed to scale with the number of processing units, ensuring high throughput even in large-scale systems.
#
# #### 3. Optimized Matrix Math Performance
#
# LPUs are optimized for matrix math performance, which is a critical component of LLM processing. By providing specialized hardware accelerators for matrix math operations, Groq LPUs can complete these operations much faster than standard GPUs.
#
# ### Why Groq LPUs Outperform Standard GPUs for LLMs
# ---------------------------------------------------
#
# #### 1. **LLM Workload Characteristics**
#
# LLMs are characterized by a large number of matrix math operations, which can be parallelized efficiently. The Groq LPU's massive parallelism and optimized matrix math performance make it an ideal platform for these workloads.
#
# #### 2. **Higher Single-Precision Throughput**
#
# Groq LPUs provide significantly higher single-precision throughput than standard GPUs, which is critical for LLMs that require a large number of single-precision matrix math operations.
#
# #### 3. **Lower Latency**
#
# The Groq LPU's low-latency interconnect fabric ensures that data moves quickly between processing units, minimizing the impact of memory access latencies.
#
# ### Conclusion
# ----------
#
# Groq LPUs provide higher throughput for LLMs than standard GPUs due to their massive parallelism, optimized matrix math performance, and high-bandwidth interconnect fabric. These features enable LPU to efficiently process the large number of matrix math operations required for LLMs, making them an attractive choice for high-performance LLM applications.
#
# By comparison to GPUs, Groq LPUs provide a more customized architecture that better addresses the specific needs of LLM workloads, allowing for higher levels of performance with better resource utilization efficiency.
# ----------------------------------------
#
# [Editor]: **Critique and Optimized Version**
#
# The provided text is well-structured and effectively conveys the advantages of Groq LPUs over standard GPUs for Large Language Models (LLMs). However, there are some areas that can be improved for better clarity, concision, and professionalism.
#
# **Optimized Version**
#
# **Groq LPUs: Unlocking High-Throughput Large Language Models**
# ===========================================================
#
# ### Introduction
#
# The rapid advancement of Large Language Models (LLMs) has created a pressing need for specialized hardware that can efficiently process and generate human-like language. Groq LPUs (Large Processor Arrays) have emerged as a game-changer in this space, offering a custom-built architecture designed to maximize throughput for LLM workloads.
#
# **Groq LPUs: A Paradigm Shift in Custom Hardware Design**
# ---------------------------------------------------
#
# Groq LPUs are built around a scalable, massively parallel architecture that provides a significant advantage over standard GPUs in high-throughput applications. By leveraging a large array of processing units, each capable of executing multiple operations simultaneously, Groq LPUs can process vast amounts of data in parallel, resulting in substantial throughput gains.
#
# ### Key Features of Groq LPUs
#
# 1. **Massive Parallelism**: Groq LPUs boast an extensive array of processing units, enabling the simultaneous execution of numerous operations and resulting in increased throughput.
# 2. **High-Bandwidth Interconnect Fabric**: The interconnect fabric in Groq LPUs is designed to scale with the number of processing units, ensuring low-latency communication and high-throughput performance.
# 3. **Optimized Matrix Math Performance**: Groq LPUs are optimized for matrix math operations, a critical component of LLM processing, allowing for faster completion of these operations compared to standard GPUs.
#
# ### Groq LPUs vs. Standard GPUs: A Performance Comparison
# --------------------------------------------------------
#
# The characteristics of LLM workloads, including a high volume of matrix math operations, make Groq LPUs an ideal platform. Key advantages of Groq LPUs over standard GPUs include:
#
# 1. **Higher Single-Precision Throughput**: Groq LPUs deliver significantly higher single-precision throughput, essential for LLMs that rely heavily on single-precision matrix math operations.
# 2. **Lower Latency**: The low-latency interconnect fabric in Groq LPUs minimizes memory access latencies, ensuring faster data transfer between processing units.
# 3. **Better Resource Utilization**: Groq LPUs provide a more customized architecture, allowing for more efficient resource utilization and higher performance levels compared to standard GPUs.
#
# ### Conclusion
# ----------
#
# In conclusion, Groq LPUs offer superior throughput for LLMs compared to standard GPUs, thanks to their massively parallel architecture, optimized matrix math performance, and high-bandwidth interconnect fabric. By addressing the specific needs of LLM workloads, Groq LPUs have established themselves as a top choice for high-performance LLM applications.
#
# **Changes Made**
#
# 1. **Simplified Introduction**: The introduction has been condensed to focus on the main point of the article.
# 2. **Removed Unnecessary Sections**: The "Breakthrough in Custom Hardware Design" section has been removed, as its content is already covered in the introduction and key features section.
# 3. **Improved Section Headings**: Section headings have been revised for better clarity and concision.
# 4. **Added Transitions**: Transitions have been added between sections to improve the article's flow and readability.
# 5. **Minor Edits**: Minor edits have been made throughout the article to enhance grammar, punctuation, and sentence structure.
# ----------------------------------------
#
# [Researcher]: **Detailed Critique and Optimized Version**
#
# The provided text is a well-structured and professional summary of the advantages of Groq LPUs over standard GPUs for Large Language Models (LLMs). However, there are some areas that can be improved for better clarity, concision, and professionalism.
#
# **Strengths:**
#
# * The text effectively conveys the advantages of Groq LPUs over standard GPUs for LLMs.
# * The structure is clear and well-organized, making it easy to follow.
# * The use of technical terms and concepts is accurate and relevant.
#
# **Weaknesses:**
#
# * The introduction is slightly lengthy and could be condensed for better focus.
# * The section on "Groq LPUs" is redundant and could be removed as its content is already covered in the introduction and key features section.
# * The use of bullet points is inconsistent and could be standardized for better clarity.
# * Some sentences could be rephrased for better grammar and sentence structure.
#
# **Optimized Version**
#
# **Groq LPUs: Unlocking High-Throughput Large Language Models**
# ===========================================================
#
# ### Introduction
#
# The rapid advancement of Large Language Models (LLMs) has created a pressing need for specialized hardware that can efficiently process and generate human-like language. Groq LPUs (Large Processor Arrays) offer a custom-built architecture designed to maximize throughput for LLM workloads.
#
# **Key Features of Groq LPUs**
#
# Groq LPUs are built around a scalable, massively parallel architecture that provides a significant advantage over standard GPUs. The main features include:
#
# * **Massive Parallelism**: An extensive array of processing units, enabling the simultaneous execution of numerous operations and resulting in increased throughput.
# * **High-Bandwidth Interconnect Fabric**: A scalable interconnect fabric ensuring low-latency communication and high-throughput performance.
# * **Optimized Matrix Math Performance**: Specialized hardware accelerators for matrix math operations, critical for LLM processing.
#
# ### Groq LPUs vs. Standard GPUs: A Performance Comparison
# --------------------------------------------------------
#
# The characteristics of LLM workloads make Groq LPUs an ideal platform. Key advantages over standard GPUs include:
#
# * **Higher Single-Precision Throughput**: Delivering significantly higher single-precision throughput, essential for LLMs.
# * **Lower Latency**: Minimizing memory access latencies through a low-latency interconnect fabric.
# * **Better Resource Utilization**: Providing a more customized architecture for efficient resource utilization and higher performance levels.
#
# ### Conclusion
# ----------
#
# Groq LPUs offer superior throughput for LLMs compared to standard GPUs, thanks to their massively parallel architecture, optimized matrix math performance, and high-bandwidth interconnect fabric. By addressing the specific needs of LLM workloads, Groq LPUs have established themselves as a top choice for high-performance LLM applications.
#
# **Changes Made:**
#
# 1. **Improved Introduction**: Condensed to focus on the main point.
# 2. **Removed Redundant Section**: Removed "Breakthrough in Custom Hardware Design" section.
# 3. **Standardized Bullet Points**: Used consistent bullet points throughout the text.
# 4. **Minor Edits**: Made minor edits for better grammar, punctuation, and sentence structure.
# ----------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3021/1274828065.py in <cell line: 1>()
#      63
#      64 # Execute the async loop inside Google Colab
# ---> 65 await run_team()
#
# /tmp/ipykernel_3021/1274828065.py in run_team()
#      59     print("--- Starting Multi-Agent Session ---")
#      60     async for message in team.run_stream(task="Explain why Groq LPUs provide higher throughput for LLMs than standard GPUs."):
# ---> 61         print(f"\n\033[{message.source}]\033: {message.content}")
#      62         print("-" * 40)
#      63
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __getattr__(self, item)
#    1024                     else:
#    1025                         # this is the current error
# -> 1026                         raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#    1027
#    1028         def __setattr__(self, name: str, value: Any) -> None:
#
# AttributeError: 'TaskResult' object has no attribute 'source'
